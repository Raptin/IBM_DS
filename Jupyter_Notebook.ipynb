# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Data Science Tools and Ecosystem Assignment

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized for the peer review assignment.

# %% [markdown]
# **Objectives:**
#  - Summary of data science tools
#  - Arithmetic expressions
#  - List of Data Science languages

# %% [markdown]
# The data science languages are:
#  1. Python
#  2. SQL
#  3. Java
#  5. R

# %% [markdown]
# The data science libraries are:
#  1. Pandas
#  2. Sci-Kit learn
#  3. matplotlib

# %% [markdown]
# | Data Science Tools |
# | ------|
# | Visual studio |
# | RStudio |
# | Jupyter IDE |

# %% [markdown]
# ### Evaluating arithmetic expressions in Python

# %%
# Simple arithmetic expression multiplying then adding numbers
(3*4)+5
# Out:
# 17

# %%
# Converting minutes to hours by dividing by 60

200 / 60
# Out:
# 3.3333333333333335

# %% [markdown]
# ## Author
# Ruan
